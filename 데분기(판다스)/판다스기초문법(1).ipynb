# %%
import pandas as pd

# %% [markdown]
# ### 판다스에서 제공하는 두 가지 데이터구조를 잘 이해해야 한다.
# - dataframe
# - Series
#
# - 첫시간에 이야기 한 내용들

# %%
import seaborn as sns

# %%
tt = sns.load_dataset('titanic')

# %%
tt # seaborn 타이타닉데이터
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 데이터프레임
type(tt)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tt['survived']) #시리즈
# Out:
# pandas.core.series.Series

# %%
#간단한 기초 문법 
#shape (행과, 열) 확인
tt.shape
# Out:
# (891, 15)

# %%
tt.shape[0]
# Out:
# 891

# %%
tt.shape[1]
# Out:
# 15

# %%
#컬럼만 보고싶다!
tt.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
tt_col=list(tt.columns)

# %%
## info() 기본적인 데이터프레임의 정보들을 알려준다.
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
## 기초통계값을 확인
tt.describe()
# 수치형 데이터의 기초통계값
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
tt.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
# 데이터의 앞과 뒤 
tt.head() #디폴트 5개
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tt.tail() #디폴트 5개
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# ### 데이터프레임의 구조를 이해했으니 행과 열로 데이터를 추출하자!
#
# - 2차원 구조 행과 열로 이뤄진 형태니 우리도 행과 열 가지고 데이터를 추출 또는 접근할 수 있다.
#
# - 열기준 ( 컬럼 기준 )
# - [col1]
# - [[col1, col2]]

# %%
tt['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
tt_sp = tt[['survived','pclass']]

# %%
tt_sp
# Out:
#      survived  pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %% [markdown]
# - 행기준( 인덱스기준으로 접근! )
#
# - 인덱스 기준으로 접근하는 법은 2가지 방버
# - ### loc : 행 인덱스 기준으로 추출 (컬럼은 문자열로도 가능), 변수의 개념으로 인덱스를 추출할 수 있다. 다만 (-1 끝값에 대한 적용은 불가)
#
# - ### iloc : 인덱스 기준-> (추출한 인덱스기준),인덱스 변수로도 가능, 모든지 번호로만 다 인식 ( 컬럼도 번호로 지정해야 한다.) (끝값 -1 가능)
#
#
# - 리스트에서 Index 접근법 하면 []
# - tt.loc[index]
# - tt.iloc[index]

# %%
tt.loc[5]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                   NaN
# sibsp                   0
# parch                   0
# fare               8.4583
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 5, dtype: object

# %%
tt.iloc[5]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                   NaN
# sibsp                   0
# parch                   0
# fare               8.4583
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 5, dtype: object

# %%
tt.iloc[-1]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexes/range.py:392, in RangeIndex.get_loc(self, key, method, tolerance)
#     391 try:
# --> 392     return self._range.index(new_key)
#     393 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 tt.loc[-1]
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
num_row= tt.shape[0]

# %%
last_index =num_row-1

# %%
last_index
# Out:
# 890

# %%
tt.loc[last_index]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt.loc[890]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt.iloc[last_index]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %% [markdown]
# - 행을 여러가지 추가해서 다양한 행 추출하는 경우!

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[[0,2,3,4,6,880]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 6      man        True    E  Southampton    no   True
# 880  woman       False  NaN  Southampton   yes  False

# %%
tt.iloc[[0,2,3,4,6,880]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 6      man        True    E  Southampton    no   True
# 880  woman       False  NaN  Southampton   yes  False

# %%
#행 과열로 접근 가능
# 컬럼을 기준으로 접근하면 -> class , 2인덱스 값을 찾고 싶다!
tt['class'].loc[2]
# Out:
# 'Third'

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - 인덱스의 유용한 점
# - 슬라이싱이 가능하다 - > range함수에서 슬라이싱 가능
#
# - [시작점:끝점:증가폭]

# %%
tt.loc[::]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[0:150:2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 142         1       3  female  24.0      1      0  15.8500        S   Third
# 144         0       2    male  18.0      0      0  11.5000        S  Second
# 146         1       3    male  27.0      0      0   7.7958        S   Third
# 148         0       2    male  36.5      0      2  26.0000        S  Second
# 150         0       2    male  51.0      0      0  12.5250        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.iloc[::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - loc, iloc에 가장 큰 차이 중 하나 ( 컬럼에 대한 접근 )
# - iloc은 모든 컬럼을 숫자로만 접근한다.
#
# - python 대부분은 행시작 열
# - tt.loc[행,열]

# %%
tt.loc[::2,['age']]
# Out:
#       age
# 0    22.0
# 2    26.0
# 4    35.0
# 6    54.0
# 8    27.0
# ..    ...
# 882  22.0
# 884  25.0
# 886  27.0
# 888   NaN
# 890  32.0
#
# [446 rows x 1 columns]

# %%
tt.loc[::2,['age','survived']]
# Out:
#       age  survived
# 0    22.0         0
# 2    26.0         1
# 4    35.0         0
# 6    54.0         0
# 8    27.0         1
# ..    ...       ...
# 882  22.0         0
# 884  25.0         0
# 886  27.0         0
# 888   NaN         0
# 890  32.0         0
#
# [446 rows x 2 columns]

# %%
#컬럼에 대한 접근은 iloc 숫자로 접근해야 한다( 숫자는 컬럼의 인덱스를 뜻한다.)
tt.iloc[::2,['age','survived']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 tt.iloc[::2,['age','survived']]
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexing.py:1564, in _iLocIndexer._getitem_tuple(self, tup)
#    1562 def _getitem_tuple(self, tup: tuple):
# -> 1564     tup = self._validate_tuple_indexer(tup)
#    1565     with suppress(IndexingError):
#    1566         return self._getitem_lowerdim(tup)
#
# ...

# %%
tt.iloc[::2,[0,3]]
# Out:
#      survived   age
# 0           0  22.0
# 2           1  26.0
# 4           0  35.0
# 6           0  54.0
# 8           1  27.0
# ..        ...   ...
# 882         0  22.0
# 884         0  25.0
# 886         0  27.0
# 888         0   NaN
# 890         0  32.0
#
# [446 rows x 2 columns]

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
num_3=list(range(0,120,3))

# %%
tt.iloc[num_3]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 12          0       3    male  20.00      0      0    8.0500        S   Third
# 15          1       2  female  55.00      0      0   16.0000        S  Second
# 18          0       3  female  31.00      1      0   18.0000        S   Third
# 21          1       2    male  34.00      0      0   13.0000        S  Second
# 24          0       3  female   8.00      3      1   21.0750        S   Third
# 27          0       1    male  19.00      3      2  263.0000        S   First
# 30          0       1    male  40.00      0      0   27.7208        C   First
# ...

# %% [markdown]
# - 행과 열을 접근하는 법을 이해했으니 -> 기초통계치에대한 값을 구하는 걸 배우고-> 응용하자!
#
# - 판다스에 제공하는 mean, sum, std.. 기초통계들 사용 가능
# - 넘파이에서 제공하는 np.mean, np.argmax, np.std 등도 사용 가능하다.

# %%
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt['fare'].mean()
# Out:
# 32.204207968574636

# %%
tt['fare'].sum()
# Out:
# 28693.9493

# %%
tt['fare'].median()
# Out:
# 14.4542

# %%
import numpy as np

# %%
np.mean(tt['fare'])
# Out:
# 32.204207968574636

# %%
np.argmax(tt['fare']) # 최대 값의 인덱스 반환
# Out:
# 258

# %%
np.argmin(tt['fare']) # 최소 값의 인덱스 반환
# Out:
# 179

# %%
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print(tt.loc[258])
print(tt.loc[179])
# Out:
# survived               1
# pclass                 1
# sex               female
# age                 35.0
# sibsp                  0
# parch                  0
# fare            512.3292
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                 NaN
# embark_town    Cherbourg
# alive                yes
# alone               True
# Name: 258, dtype: object
# survived                 0
# pclass                   3
# sex                   male
# age                   36.0
# sibsp                    0
# parch                    0
# fare                   0.0
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 179, dtype: object

# %%
## pclass별 fare 평균은?, 합은?
## 데이터에 대한 접근을 뎁스를 더 들어가서 원하는 값을 찾을 경우 

tt['fare'].mean()
# Out:
# 32.204207968574636

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
## groupby - 그룹별로 묶는다.
## 내가 원하는 값을 추출하기 위해 그룹별 묶어서 값을 반환
## groupby('그룹을 묶을 컬럼')['통계치를 볼 컬럼'].원하는 통계치()
tt.groupby('pclass')

# %%
tt.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
tt.groupby('pclass')['fare'].sum()
# Out:
# pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: fare, dtype: float64

# %%
tt.groupby('pclass')['fare','age'].mean()
# Out:
# /var/folders/sz/167qwb595mqgwry5mm8685n00000gn/T/ipykernel_36439/770508112.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tt.groupby('pclass')['fare','age'].mean()
#              fare        age
# pclass
# 1       84.154687  38.233441
# 2       20.662183  29.877630
# 3       13.675550  25.140620

# %%
tt.groupby('pclass')[['fare','age']].mean()
# Out:
#              fare        age
# pclass
# 1       84.154687  38.233441
# 2       20.662183  29.877630
# 3       13.675550  25.140620

# %%
tt.groupby('sex')['survived'].sum()
# 생존자 수
# 남성은 109 생존
# 여성은 233 생존
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %% [markdown]
# - 원하는 값을 접근하기 위해서, 또는 추출하기 위해서?
# - 데이프레임을 어떤 식으로 접근해야 하는가?
#
# - 행과 열로 접근
# - 열과 행으로 접근해도 된다.
#
# Q1.  - survied, fare, class 컬럼의 2~40개 인덱스 데이터를 추출하고 싶다!

# %%
# 열->행
tt[['survived','fare','class']].loc[2:40]
# Out:
#     survived      fare   class
# 2          1    7.9250   Third
# 3          1   53.1000   First
# 4          0    8.0500   Third
# 5          0    8.4583   Third
# 6          0   51.8625   First
# 7          0   21.0750   Third
# 8          1   11.1333   Third
# 9          1   30.0708  Second
# 10         1   16.7000   Third
# 11         1   26.5500   First
# 12         0    8.0500   Third
# 13         0   31.2750   Third
# 14         0    7.8542   Third
# 15         1   16.0000  Second
# 16         0   29.1250   Third
# 17         1   13.0000  Second
# 18         0   18.0000   Third
# 19         1    7.2250   Third
# 20         0   26.0000  Second
# 21         1   13.0000  Second
# 22         1    8.0292   Third
# 23         1   35.5000   First
# 24         0   21.0750   Third
# 25         1   31.3875   Third
# 26         0    7.2250   Third
# 27         0  263.0000   First
# 28         1    7.8792   Third
# 29         0    7.8958   Third
# 30         0   27.7208   First
# ...

# %%
# 행->열
tt.loc[2:40][['survived','fare','class']]
# Out:
#     survived      fare   class
# 2          1    7.9250   Third
# 3          1   53.1000   First
# 4          0    8.0500   Third
# 5          0    8.4583   Third
# 6          0   51.8625   First
# 7          0   21.0750   Third
# 8          1   11.1333   Third
# 9          1   30.0708  Second
# 10         1   16.7000   Third
# 11         1   26.5500   First
# 12         0    8.0500   Third
# 13         0   31.2750   Third
# 14         0    7.8542   Third
# 15         1   16.0000  Second
# 16         0   29.1250   Third
# 17         1   13.0000  Second
# 18         0   18.0000   Third
# 19         1    7.2250   Third
# 20         0   26.0000  Second
# 21         1   13.0000  Second
# 22         1    8.0292   Third
# 23         1   35.5000   First
# 24         0   21.0750   Third
# 25         1   31.3875   Third
# 26         0    7.2250   Third
# 27         0  263.0000   First
# 28         1    7.8792   Third
# 29         0    7.8958   Third
# 30         0   27.7208   First
# ...

# %%
#판다스의 데이터 추출 원리를 보면
tt[['survived','fare','class']].loc[2:40]['fare'].mean()
# Out:
# 29.925746153846156

# %%
tt[['survived','fare','class']].loc[2:40]['fare'].mean()
# Out:
# 29.925746153846156

# %% [markdown]
# ## 데이터 분석에 필요한 기초 문법(2)
# - query()
# - sort_values()
# - groupby()
# - assign(), lambda
# - agg()
# - merge() - 따로 병합은 1시간 동안 추가로 진행할 예정
# - concat() - 따로 병합은 1시간 동안 추가로 진행할 예정
# - str() -> 1~2시간 자연어처리 진행하면서 할 예정
# - 시계열 ->1~2시간정도 따로 시계열 데이터 전처리를 배울 예정

# %% [markdown]
# - query()
# - 데이터를 추출하기 위한 조건
# - 내가 원하는 데이터를 추출하기 위해서 추가적으로 사용하는 문법
#
# - e.g. embarked = s인경우? , alone = Ture 참인 경우?, fare > 평균이상인경우?
# - ### 요소의 특정값을 접근해서 데이터를 추출하는 케이스
#
# - tt.query('요구조건')

# %%
tt.query('''embarked == "S" ''')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query('''embarked == 'C' ''')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
tt.query('''embarked != "S" ''')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
tt.fare.mean()
# Out:
# 32.204207968574636

# %%
tt['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
# 수치형 데이터로 접근해 보기!
tt.query("fare >32.204207968574636") # 해당 평균이 값 초과인 경우 추출 가능
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query("fare >=32.204207968574636 ")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - 논리연산자 이용해서 다양한 케이스를 추가할 수 있다.
# - and, or

# %%
tt.query("fare >=32.204207968574636 and age >30")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 35          0       1    male  42.0      1      0   52.0000        S  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 838         1       3    male  32.0      0      0   56.4958        S  Third
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query("fare >=32.204207968574636 or age >30")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 873         0       3    male  47.0      0      0   9.0000        S  Third
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 881         0       3    male  33.0      0      0   7.8958        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 문자, 숫자 다 같이 조건에 넣어서 진행해 보자!
tt.query('''embarked != "S" and fare >=32.204207968574636 and age<30''')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 34          0       1    male  28.0      1      0   82.1708        C   First
# 43          1       2  female   3.0      1      2   41.5792        C  Second
# 97          1       1    male  23.0      0      1   63.3583        C   First
# 118         0       1    male  24.0      0      1  247.5208        C   First
# 139         0       1    male  24.0      0      0   79.2000        C   First
# 291         1       1  female  19.0      1      0   91.0792        C   First
# 307         1       1  female  17.0      1      0  108.9000        C   First
# 310         1       1  female  24.0      0      0   83.1583        C   First
# 311         1       1  female  18.0      2      2  262.3750        C   First
# 329         1       1  female  16.0      0      1   57.9792        C   First
# 369         1       1  female  24.0      0      0   69.3000        C   First
# ...

# %% [markdown]
# - 우리가 지금까지 배운 것들을 다 같이 응용해보기!
# - 컬럼, 인덱스 기준으로 데이터를 추출할 수 있다.
# - query()이용해서 해당 데이터의 요소의 값의 기준으로 데이터를 추출할 수 있다!
#
#
#
# - ### Q1. embarked != "S" and fare >=32.204207968574636 and age<30 이 승객들의 생존자는?
# - 1생존한 경우 -> 1을 다 더하면 생존자

# %%
tt.query('''embarked != "S" and fare >=32.204207968574636 and age<30''')['survived'].sum()
# Out:
# 20

# %%
tt[['survived','embarked','fare','age']].query('''embarked != "S" and fare >=32.204207968574636 and age<30''')['survived'].sum()
# Out:
# 20

# %% [markdown]
# - 복습시에
# - 코드를 드리면 이 코드를 그대로 복사 붙여넣기로 해서 제출하는 게 아니라, 직접 다른 컬럼을 넣어보면서 계산한 결과를 보고 공부하시면 돼요!
#
# - Q. 질문을 먼저 하고 -> 그 질문에 대한 답변을 코드로 작성해서 확인하면 된다.
